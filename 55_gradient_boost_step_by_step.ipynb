# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaykumar080286/MachineLearning/blob/main/55_gradient_boost_step_by_step.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor, plot_tree

# %%
np.random.seed(42)
X = np.random.rand(100, 1) - 0.5
y = 3*X[:, 0]**2 + 0.05 * np.random.randn(100)

# %%
df=pd.DataFrame()

# %%
df['X']=X.reshape(100)

# %%
df['y']=y

# %%
X.shape
# Out:
# (100, 1)

# %%
df
# Out:
#            X         y
# 0  -0.125460  0.051573
# 1   0.450714  0.594480
# 2   0.231994  0.166052
# 3   0.098658 -0.070178
# 4  -0.343981  0.343986
# ..       ...       ...
# 95 -0.006204 -0.040675
# 96  0.022733 -0.002305
# 97 -0.072459  0.032809
# 98 -0.474581  0.689516
# 99 -0.392109  0.502607
#
# [100 rows x 2 columns]

# %%
plt.scatter(df['X'],df['y'])
plt.title('X vs Y')
# Out:
# Text(0.5, 1.0, 'X vs Y')

# %%
df.head(4)
# Out:
#           X         y
# 0 -0.125460  0.051573
# 1  0.450714  0.594480
# 2  0.231994  0.166052
# 3  0.098658 -0.070178

# %%
df["y_pred1"]=df["y"].mean()

# %%
df.head(5)
# Out:
#           X         y   y_pred1
# 0 -0.125460  0.051573  0.265458
# 1  0.450714  0.594480  0.265458
# 2  0.231994  0.166052  0.265458
# 3  0.098658 -0.070178  0.265458
# 4 -0.343981  0.343986  0.265458

# %%
df["res1"]=df["y"]-df["y_pred1"]

# %%
df.head(8)
# Out:
#           X         y   y_pred1      res1
# 0 -0.125460  0.051573  0.265458 -0.213885
# 1  0.450714  0.594480  0.265458  0.329021
# 2  0.231994  0.166052  0.265458 -0.099407
# 3  0.098658 -0.070178  0.265458 -0.335636
# 4 -0.343981  0.343986  0.265458  0.078528
# 5 -0.344005  0.372875  0.265458  0.107417
# 6 -0.441916  0.659765  0.265458  0.394307
# 7  0.366176  0.376341  0.265458  0.110883

# %%
plt.scatter(df['X'],df['y'])
plt.plot(df["X"],df["y_pred1"], color="red")

# %%
dt=DecisionTreeRegressor(max_depth=8)
X1=df["X"].values.reshape(100,1)
y1=df["res1"].values

# %%
dt.fit(X1,y1)
# Out:
# DecisionTreeRegressor(max_depth=8)

# %%
plot_tree(dt)
plt.show()

# %%
X_test = np.linspace(-0.5, 0.5, 500)

# %%
y_pred2=0.265458+dt.predict(X_test.reshape(500,1))

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
plt.plot(X_test, y_pred2, linewidth=2,color='red')
plt.scatter(df['X'],df['y'])

# %%
df['pred2'] = 0.265458 + dt.predict(df['X'].values.reshape(100,1))

# %%
df.head(10)
# Out:
#           X         y   y_pred1      res1   y_pred2      res2     pred2
# 0 -0.125460  0.051573  0.265458 -0.213885 -0.226577  0.012691  0.038881
# 1  0.450714  0.594480  0.265458  0.329021  0.332168 -0.003146  0.597626
# 2  0.231994  0.166052  0.265458 -0.099407 -0.085517 -0.013890  0.179941
# 3  0.098658 -0.070178  0.265458 -0.335636 -0.270759 -0.064877 -0.005301
# 4 -0.343981  0.343986  0.265458  0.078528  0.068559  0.009969  0.334017
# 5 -0.344005  0.372875  0.265458  0.107417  0.107417  0.000000  0.372875
# 6 -0.441916  0.659765  0.265458  0.394307  0.394307  0.000000  0.659765
# 7  0.366176  0.376341  0.265458  0.110883  0.110883  0.000000  0.376341
# 8  0.101115 -0.009752  0.265458 -0.275210 -0.270759 -0.004451 -0.005301
# 9  0.208073  0.104795  0.265458 -0.160664 -0.142614 -0.018050  0.122844

# %%
df["res2"]=df["y"]-df["pred2"]

# %%
df.head(4)
# Out:
#           X         y   y_pred1      res1   y_pred2      res2     pred2
# 0 -0.125460  0.051573  0.265458 -0.213885 -0.226577  0.012692  0.038881
# 1  0.450714  0.594480  0.265458  0.329021  0.332168 -0.003146  0.597626
# 2  0.231994  0.166052  0.265458 -0.099407 -0.085517 -0.013889  0.179941
# 3  0.098658 -0.070178  0.265458 -0.335636 -0.270759 -0.064876 -0.005301

# %%
dt1=DecisionTreeRegressor(max_depth=8)
X2=df["X"].values.reshape(100,1)
y2=df["res2"].values

# %%
dt1.fit(X2,y2)
# Out:
# DecisionTreeRegressor(max_depth=8)

# %%
y_pred3=0.265458+sum(reg.predict(X_test.reshape(500,1)) for reg in [dt,dt1])

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
plt.plot(X_test, y_pred3, linewidth=2,color='red')
plt.scatter(df['X'],df['y'])
plt.title('X vs y')
# Out:
# Text(0.5, 1.0, 'X vs y')

# %%
def gradient_boost(X,y,number,lr,count=1,regs=[],foo=None):

  if number == 0:
     return
  else:
    # do gradient boosting
    print(count)

    if count > 1:
      y = y - regs[-1].predict(X)
    else:
      foo = y

    tree_reg = DecisionTreeRegressor(max_depth=5, random_state=42)
    tree_reg.fit(X, y)

    regs.append(tree_reg)

    x1 = np.linspace(-0.5, 0.5, 500)
    y_pred = sum(lr * regressor.predict(x1.reshape(-1, 1)) for regressor in regs)

    print(number)
    plt.figure()
    plt.plot(x1, y_pred, linewidth=2)
    plt.plot(X[:, 0], foo,"r.")
    plt.show()

    gradient_boost(X,y,number-1,lr,count+1,regs,foo=foo)

# %%
np.random.seed(42)
X = np.random.rand(100, 1) - 0.5
y = 3*X[:, 0]**2 + 0.05 * np.random.randn(100)

# %%
gradient_boost(X,y,5,lr=1)
# Out:
# 1
# 5
# 2
# 4
# 3
# 3
# 4
# 2
# 5
# 1
