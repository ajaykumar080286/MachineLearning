# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaykumar080286/MachineLearning1/blob/main/days49.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement (3).csv')

# %%
df.sample(5)
# Out:
#      cgpa  package
# 58   6.92     3.09
# 24   6.53     2.71
# 113  6.94     2.37
# 141  6.76     3.18
# 175  7.04     3.50

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package (in lacks)')
# Out:
# Text(0, 0.5, 'Package (in lacks)')

# %%
X=df.iloc[:,0:1]
y=df.iloc[:,-1]
X
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(X,y, test_size=0.2, random_state=2)

# %%
from sklearn.linear_model import  LinearRegression
lr=LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
plt.scatter(df['cgpa'], df['package'])
plt.plot(X_train, lr.predict(X_train), color="red")
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
m=lr.coef_
m
# Out:
# array([0.55795197])

# %%
b=lr.intercept_
b
# Out:
# np.float64(-0.8961119222429144)

# %%
y_pred
# Out:
# array([3.89111601, 3.09324469, 2.38464568, 2.57434935, 1.6537286 ,
#        1.77647803, 2.07219258, 2.93143862, 3.76278706, 2.93701814,
#        4.09197872, 3.51170867, 2.97049525, 2.40138424, 3.18809652,
#        3.46707251, 1.94386362, 3.24389172, 2.97607477, 3.41685683,
#        2.55761079, 3.16577844, 2.85890486, 3.12114229, 3.68467378,
#        2.8700639 , 3.49497011, 3.34432308, 3.91901361, 1.96060218,
#        3.65119666, 3.2104146 , 3.74046898, 2.7863711 , 2.78079158,
#        3.27178932, 3.52844723, 2.61340599, 2.65804215, 2.71383735])

# %%
y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 0.2884710931878175

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 0.12129235313495527

# %%
r2_score(y_test, y_pred)
# Out:
# 0.780730147510384

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# np.float64(0.34827051717731616)

# %%
r2=r2_score(y_test, y_pred)
r2
# Out:
# 0.780730147510384

# %%
n=X_test.shape[0]
k=1

# %%
adr2=1- ((1-r2)*(n-1)/(n-1-k))

# %%
adr2
# Out:
# 0.7749598882343415

# %%
new_df=df.copy()

# %%
new_df.shape
# Out:
# (200, 2)

# %%
new_df["Temp"]= np.random.random(200)

# %%
new_df.head()
# Out:
#    cgpa  package      Temp
# 0  6.89     3.26  0.203507
# 1  5.12     1.98  0.651032
# 2  7.82     3.25  0.401249
# 3  7.42     3.67  0.624179
# 4  6.94     3.57  0.029335

# %%
new_df=new_df[['cgpa','Temp', 'package']]

# %%
new_df.head()
# Out:
#    cgpa      Temp  package
# 0  6.89  0.203507     3.26
# 1  5.12  0.651032     1.98
# 2  7.82  0.401249     3.25
# 3  7.42  0.624179     3.67
# 4  6.94  0.029335     3.57

# %%
plt.scatter(new_df['Temp'], new_df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package (in lacks)')
# Out:
# Text(0, 0.5, 'Package (in lacks)')

# %%
X=new_df.iloc[:,0:2]

# %%
y=new_df.iloc[:,-1]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
X_train, X_test, y_train, y_test= train_test_split(X,y, test_size=0.2, random_state=2)

# %%
lr=LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
y_pred
# Out:
# array([3.90914162, 3.07714281, 2.36362285, 2.61433216, 1.62660367,
#        1.74835249, 2.06361253, 2.89891301, 3.793866  , 2.92240814,
#        4.04369931, 3.50334929, 2.97351242, 2.42079785, 3.21483525,
#        3.47342007, 1.97149616, 3.23033752, 2.93981904, 3.41406627,
#        2.56335233, 3.13703013, 2.87986868, 3.12373417, 3.70491367,
#        2.84812218, 3.47879759, 3.29659516, 3.87489017, 1.99408436,
#        3.6076099 , 3.19867573, 3.76234557, 2.80918959, 2.73522648,
#        3.24380301, 3.56250338, 2.64914964, 2.6597711 , 2.69685055])

# %%
r2=r2_score(y_test, y_pred)

# %%
r2
# Out:
# 0.7811774620080871

# %%
adr2=1- ((1-r2)*(n-1)/(n-1-2))

# %%
adr2
# Out:
# 0.769349216711227

# %%
new_df1=df.copy()

# %%
new_df1
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
new_df1['iq']=new_df1['package'] + (np.random.randint(-12,12,200)/10)

# %%
new_df1=new_df1[['cgpa','iq', 'package']]

# %%
plt.scatter(new_df1['iq'], new_df1['package'])
plt.xlabel('CGPA')
plt.ylabel('Package (in lacks)')
# Out:
# Text(0, 0.5, 'Package (in lacks)')

# %%
X = new_df1.iloc[:,0:2]
y = new_df1.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train
# Out:
#      cgpa    iq
# 137  7.14  4.13
# 163  8.93  2.71
# 111  5.42  1.15
# 123  5.10  2.50
# 109  7.77  3.86
# ..    ...   ...
# 43   7.66  3.76
# 22   6.14  3.00
# 72   7.78  3.42
# 15   7.25  2.03
# 168  8.65  2.52
#
# [160 rows x 2 columns]

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
print("R2 score",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
X_test.shape[0]
# Out:
# R2 score 0.8394796048152151
# 40

# %%
1 - ((1-r2)*(40-1)/(40-1-2))
# Out:
# 0.8308028266971186
