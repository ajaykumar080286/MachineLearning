# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaykumar080286/MachineLearning/blob/main/Bagging_Vs_Random_forest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier
from sklearn.tree import plot_tree
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt

# %%
X,y= make_classification(n_features=5, n_informative=5, n_redundant=0, n_clusters_per_class=1)

# %%
df=pd.DataFrame(X, columns=['col1','col2', 'col3', 'col4', 'col5'])
df['target']=y

# %%
df.head()
# Out:
#        col1      col2      col3      col4      col5  target
# 0 -0.598491  1.046174 -1.660161  1.730400 -1.146065       1
# 1 -0.952275 -0.561275 -1.333028  1.006278 -1.072173       1
# 2  1.401676  0.908332 -2.473941 -0.216592  0.726040       0
# 3 -2.107882 -0.382074 -0.546743  1.589008 -1.093150       1
# 4  0.453318 -0.250864 -2.385608  1.289837  1.121738       0

# %%
X_train=df.iloc[:,:5]
y_train=df.iloc[:,-1]

# %%
bag=BaggingClassifier(max_features=2)
bag.fit(X_train, y_train)
# Out:
# BaggingClassifier(max_features=2)

# %%
# Out:
# DecisionTreeClassifier(random_state=467514673)

# %%
plot_tree(bag.estimators_[0])
# Out:
# [Text(0.4166666666666667, 0.9285714285714286, 'x[0] <= -0.537\ngini = 0.442\nsamples = 58\nvalue = [67, 33]'),
#  Text(0.3333333333333333, 0.7857142857142857, 'gini = 0.0\nsamples = 18\nvalue = [0, 25]'),
#  Text(0.375, 0.8571428571428572, 'True  '),
#  Text(0.5, 0.7857142857142857, 'x[0] <= 0.243\ngini = 0.191\nsamples = 40\nvalue = [67, 8]'),
#  Text(0.45833333333333337, 0.8571428571428572, '  False'),
#  Text(0.3333333333333333, 0.6428571428571429, 'x[1] <= 0.131\ngini = 0.48\nsamples = 9\nvalue = [9, 6]'),
#  Text(0.25, 0.5, 'x[0] <= -0.238\ngini = 0.375\nsamples = 5\nvalue = [2, 6]'),
#  Text(0.16666666666666666, 0.35714285714285715, 'x[1] <= -1.354\ngini = 0.5\nsamples = 2\nvalue = [2, 2]'),
#  Text(0.08333333333333333, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 2]'),
#  Text(0.25, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(0.3333333333333333, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 4]'),
#  Text(0.4166666666666667, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [7, 0]'),
#  Text(0.6666666666666666, 0.6428571428571429, 'x[1] <= -1.331\ngini = 0.064\nsamples = 31\nvalue = [58, 2]'),
#  Text(0.5833333333333334, 0.5, 'gini = 0.0\nsamples = 16\nvalue = [37, 0]'),
#  Text(0.75, 0.5, 'x[1] <= -1.273\ngini = 0.159\nsamples = 15\nvalue = [21, 2]'),
#  Text(0.6666666666666666, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8333333333333334, 0.35714285714285715, 'x[1] <= -1.108\ngini = 0.087\nsamples = 14\nvalue = [21, 1]'),
#  Text(0.75, 0.21428571428571427, 'x[0] <= 1.056\ngini = 0.444\nsamples = 2\nvalue = [2, 1]'),
#  Text(0.6666666666666666, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8333333333333334, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [2, 0]'),
#  Text(0.9166666666666666, 0.21428571428571427, 'gini = 0.0\nsamples = 12\nvalue = [19, 0]')]

# %%
rf=RandomForestClassifier(max_features=2)
rf.fit(X_train, y_train)
plot_tree(rf.estimators_[0])
# Out:
# [Text(0.375, 0.9166666666666666, 'x[0] <= -0.184\ngini = 0.476\nsamples = 61\nvalue = [39, 61]'),
#  Text(0.16666666666666666, 0.75, 'x[4] <= 1.463\ngini = 0.128\nsamples = 31\nvalue = [4, 54]'),
#  Text(0.2708333333333333, 0.8333333333333333, 'True  '),
#  Text(0.08333333333333333, 0.5833333333333334, 'gini = 0.0\nsamples = 29\nvalue = [0, 54]'),
#  Text(0.25, 0.5833333333333334, 'gini = 0.0\nsamples = 2\nvalue = [4, 0]'),
#  Text(0.5833333333333334, 0.75, 'x[3] <= 1.073\ngini = 0.278\nsamples = 30\nvalue = [35, 7]'),
#  Text(0.4791666666666667, 0.8333333333333333, '  False'),
#  Text(0.4166666666666667, 0.5833333333333334, 'x[3] <= -0.798\ngini = 0.083\nsamples = 16\nvalue = [22, 1]'),
#  Text(0.3333333333333333, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5, 0.4166666666666667, 'gini = 0.0\nsamples = 15\nvalue = [22, 0]'),
#  Text(0.75, 0.5833333333333334, 'x[0] <= 0.871\ngini = 0.432\nsamples = 14\nvalue = [13, 6]'),
#  Text(0.6666666666666666, 0.4166666666666667, 'gini = 0.0\nsamples = 8\nvalue = [9, 0]'),
#  Text(0.8333333333333334, 0.4166666666666667, 'x[0] <= 1.477\ngini = 0.48\nsamples = 6\nvalue = [4, 6]'),
#  Text(0.75, 0.25, 'x[4] <= -0.653\ngini = 0.245\nsamples = 4\nvalue = [1, 6]'),
#  Text(0.6666666666666666, 0.08333333333333333, 'gini = 0.0\nsamples = 3\nvalue = [0, 6]'),
#  Text(0.8333333333333334, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9166666666666666, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [3, 0]')]
