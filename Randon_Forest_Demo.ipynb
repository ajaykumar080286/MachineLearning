# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaykumar080286/MachineLearning/blob/main/Randon_Forest_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

from sklearn.datasets import make_circles
import matplotlib.pyplot as plt
import numpy as np

# %%
X,y =make_circles(n_samples=500, factor=0.1, noise=0.35, random_state=42)

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2)

# %%
X.shape
# Out:
# (500, 2)

# %%
plt.scatter(X[:,0], X[:,1], c=y)

# %%
dt=DecisionTreeClassifier(random_state=42)

# %%
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
plt.figure(figsize=(12,8))

# %%
X_range=np.linspace(X.min(), X.max(), 100)
XX1, XX2=np.meshgrid(X_range,X_range)

# %%
query_point=np.c_[XX1.ravel(), XX2.ravel()]

# %%
y_hat = dt.predict(query_point)
y_hat=y_hat.reshape(XX1.shape)

# %%
plt.contourf(XX1, XX2, y_hat, alpha=0.2)
plt.scatter(X[:,0], X[:,1], c=y, cmap='viridis', alpha=.7)
plt.title("Decision tree")
plt.show()
