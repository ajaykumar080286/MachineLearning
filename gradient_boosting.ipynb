# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaykumar080286/MachineLearning/blob/main/gradient_boosting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import GradientBoostingRegressor

# %%
# Define the data
data = {
    'R&D Spend': [0, 11, 36],
    'Administration': [165.0, 101.0, 29.0],
    'Marketing Spend': [137.0, 92.0, 127.0],
    'Profit': [192.0, 144.0, 91.0]
}

# Create the DataFrame
df = pd.DataFrame(data)

# %%
df
# Out:
#    R&D Spend  Administration  Marketing Spend  Profit
# 0          0           165.0            137.0   192.0
# 1         11           101.0             92.0   144.0
# 2         36            29.0            127.0    91.0

# %%
df['f0(x)']=df['Profit'].mean()

# %%
df
# Out:
#    R&D Spend  Administration  Marketing Spend  Profit       f0(x)
# 0          0           165.0            137.0   192.0  142.333333
# 1         11           101.0             92.0   144.0  142.333333
# 2         36            29.0            127.0    91.0  142.333333

# %%
df['ri1']= df['Profit']-df['f0(x)']

# %%
df
# Out:
#    R&D Spend  Administration  Marketing Spend  Profit       f0(x)        ri1
# 0          0           165.0            137.0   192.0  142.333333  49.666667
# 1         11           101.0             92.0   144.0  142.333333   1.666667
# 2         36            29.0            127.0    91.0  142.333333 -51.333333

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree

# %%
dt1=DecisionTreeRegressor(max_depth=1)

# %%
dt1.fit(df.iloc[:,0:3].values,df['ri1'])
# Out:
# DecisionTreeRegressor(max_depth=1)

# %%
plot_tree(dt1)
# Out:
# [Text(0.5, 0.75, 'x[0] <= 23.5\nsquared_error = 1701.556\nsamples = 3\nvalue = -0.0'),
#  Text(0.25, 0.25, 'squared_error = 576.0\nsamples = 2\nvalue = 25.667'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'squared_error = 0.0\nsamples = 1\nvalue = -51.333'),
#  Text(0.625, 0.5, '  False')]
